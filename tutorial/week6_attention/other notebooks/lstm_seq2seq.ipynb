# %% [markdown]
# # Character-level recurrent sequence-to-sequence model
#
# **Author:** [fchollet](https://twitter.com/fchollet)<br>
# **Date created:** 2017/09/29<br>
# **Last modified:** 2020/04/26<br>
# **Description:** Character-level recurrent sequence-to-sequence model.

# %% [markdown]
# ## Introduction
#
# This example demonstrates how to implement a basic character-level
# recurrent sequence-to-sequence model. We apply it to translating
# short English sentences into short French sentences,
# character-by-character. Note that it is fairly unusual to
# do character-level machine translation, as word-level
# models are more common in this domain.
#
# **Summary of the algorithm**
#
# - We start with input sequences from a domain (e.g. English sentences)
#     and corresponding target sequences from another domain
#     (e.g. French sentences).
# - An encoder LSTM turns input sequences to 2 state vectors
#     (we keep the last LSTM state and discard the outputs).
# - A decoder LSTM is trained to turn the target sequences into
#     the same sequence but offset by one timestep in the future,
#     a training process called "teacher forcing" in this context.
#     It uses as initial state the state vectors from the encoder.
#     Effectively, the decoder learns to generate `targets[t+1...]`
#     given `targets[...t]`, conditioned on the input sequence.
# - In inference mode, when we want to decode unknown input sequences, we:
#     - Encode the input sequence into state vectors
#     - Start with a target sequence of size 1
#         (just the start-of-sequence character)
#     - Feed the state vectors and 1-char target sequence
#         to the decoder to produce predictions for the next character
#     - Sample the next character using these predictions
#         (we simply use argmax).
#     - Append the sampled character to the target sequence
#     - Repeat until we generate the end-of-sequence character or we
#         hit the character limit.

# %% [markdown]
# ## Setup

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras

# %% [markdown]
# ## Download the data

# %%
# !!curl -O http://www.manythings.org/anki/fra-eng.zip
# !!unzip fra-eng.zip
# Out:
# ["'unzip' is not recognized as an internal or external command,",
#  'operable program or batch file.']

# %% [markdown]
# ## Configuration

# %%
batch_size = 64  # Batch size for training.
epochs = 100  # Number of epochs to train for.
latent_dim = 256  # Latent dimensionality of the encoding space.
num_samples = 10000  # Number of samples to train on.
# Path to the data txt file on disk.
data_path = "fra.txt"

# %% [markdown]
# ## Prepare the data

# %%
# Vectorize the data.
input_texts = []
target_texts = []
input_characters = set()
target_characters = set()
with open(data_path, "r", encoding="utf-8") as f:
    lines = f.read().split("\n")
for line in lines[: min(num_samples, len(lines) - 1)]:
    input_text, target_text, _ = line.split("\t")
    # We use "tab" as the "start sequence" character
    # for the targets, and "\n" as "end sequence" character.
    target_text = "\t" + target_text + "\n"
    input_texts.append(input_text)
    target_texts.append(target_text)
    for char in input_text:
        if char not in input_characters:
            input_characters.add(char)
    for char in target_text:
        if char not in target_characters:
            target_characters.add(char)

input_characters = sorted(list(input_characters))
target_characters = sorted(list(target_characters))
num_encoder_tokens = len(input_characters)
num_decoder_tokens = len(target_characters)
max_encoder_seq_length = max([len(txt) for txt in input_texts])
max_decoder_seq_length = max([len(txt) for txt in target_texts])

print("Number of samples:", len(input_texts))
print("Number of unique input tokens:", num_encoder_tokens)
print("Number of unique output tokens:", num_decoder_tokens)
print("Max sequence length for inputs:", max_encoder_seq_length)
print("Max sequence length for outputs:", max_decoder_seq_length)

input_token_index = dict([(char, i) for i, char in enumerate(input_characters)])
target_token_index = dict([(char, i) for i, char in enumerate(target_characters)])

encoder_input_data = np.zeros(
    (len(input_texts), max_encoder_seq_length, num_encoder_tokens), dtype="float32"
)
decoder_input_data = np.zeros(
    (len(input_texts), max_decoder_seq_length, num_decoder_tokens), dtype="float32"
)
decoder_target_data = np.zeros(
    (len(input_texts), max_decoder_seq_length, num_decoder_tokens), dtype="float32"
)

for i, (input_text, target_text) in enumerate(zip(input_texts, target_texts)):
    for t, char in enumerate(input_text):
        encoder_input_data[i, t, input_token_index[char]] = 1.0
    encoder_input_data[i, t + 1 :, input_token_index[" "]] = 1.0
    for t, char in enumerate(target_text):
        # decoder_target_data is ahead of decoder_input_data by one timestep
        decoder_input_data[i, t, target_token_index[char]] = 1.0
        if t > 0:
            # decoder_target_data will be ahead by one timestep
            # and will not include the start character.
            decoder_target_data[i, t - 1, target_token_index[char]] = 1.0
    decoder_input_data[i, t + 1 :, target_token_index[" "]] = 1.0
    decoder_target_data[i, t:, target_token_index[" "]] = 1.0
# Out:
# Number of samples: 10000
# Number of unique input tokens: 70
# Number of unique output tokens: 93
# Max sequence length for inputs: 14
# Max sequence length for outputs: 59

# %% [markdown]
# ## Build the model

# %%
# Define an input sequence and process it.
encoder_inputs = keras.Input(shape=(None, num_encoder_tokens))
encoder = keras.layers.LSTM(latent_dim, return_state=True)
encoder_outputs, state_h, state_c = encoder(encoder_inputs)

# We discard `encoder_outputs` and only keep the states.
encoder_states = [state_h, state_c]

# Set up the decoder, using `encoder_states` as initial state.
decoder_inputs = keras.Input(shape=(None, num_decoder_tokens))

# We set up our decoder to return full output sequences,
# and to return internal states as well. We don't use the
# return states in the training model, but we will use them in inference.
decoder_lstm = keras.layers.LSTM(latent_dim, return_sequences=True, return_state=True)
decoder_outputs, _, _ = decoder_lstm(decoder_inputs, initial_state=encoder_states)
decoder_dense = keras.layers.Dense(num_decoder_tokens, activation="softmax")
decoder_outputs = decoder_dense(decoder_outputs)

# Define the model that will turn
# `encoder_input_data` & `decoder_input_data` into `decoder_target_data`
model = keras.Model([encoder_inputs, decoder_inputs], decoder_outputs)

# %% [markdown]
# ## Train the model

# %%
model.compile(
    optimizer="rmsprop", loss="categorical_crossentropy", metrics=["accuracy"]
)
model.fit(
    [encoder_input_data, decoder_input_data],
    decoder_target_data,
    batch_size=batch_size,
    epochs=epochs,
    validation_split=0.2,
)
# Save model
model.save("s2s")
# Out:
# Epoch 1/100
# 125/125 [==============================] - 13s 106ms/step - loss: 1.1348 - accuracy: 0.7376 - val_loss: 1.0354 - val_accuracy: 0.7155
# Epoch 2/100
# 125/125 [==============================] - 12s 95ms/step - loss: 0.8080 - accuracy: 0.7796 - val_loss: 0.7801 - val_accuracy: 0.7855
# Epoch 3/100
# 125/125 [==============================] - 12s 94ms/step - loss: 0.6536 - accuracy: 0.8172 - val_loss: 0.6709 - val_accuracy: 0.8059
# Epoch 4/100
# 125/125 [==============================] - 12s 92ms/step - loss: 0.5644 - accuracy: 0.8358 - val_loss: 0.5995 - val_accuracy: 0.8253
# Epoch 5/100
# 125/125 [==============================] - 12s 93ms/step - loss: 0.5150 - accuracy: 0.8495 - val_loss: 0.5717 - val_accuracy: 0.8345
# Epoch 6/100
# 125/125 [==============================] - 12s 96ms/step - loss: 0.4808 - accuracy: 0.8588 - val_loss: 0.5308 - val_accuracy: 0.8462
# Epoch 7/100
# 125/125 [==============================] - 12s 93ms/step - loss: 0.4534 - accuracy: 0.8661 - val_loss: 0.5076 - val_accuracy: 0.8514
# Epoch 8/100
# 125/125 [==============================] - 12s 93ms/step - loss: 0.4308 - accuracy: 0.8718 - val_loss: 0.4940 - val_accuracy: 0.8545
# Epoch 9/100
# 125/125 [==============================] - 12s 94ms/step - loss: 0.4098 - accuracy: 0.8779 - val_loss: 0.4788 - val_accuracy: 0.8584
# Epoch 10/100
# 125/125 [==============================] - 12s 94ms/step - loss: 0.3915 - accuracy: 0.8830 - val_loss: 0.4671 - val_accuracy: 0.8628
# Epoch 11/100
# 125/125 [==============================] - 12s 97ms/step - loss: 0.3740 - accuracy: 0.8881 - val_loss: 0.4553 - val_accuracy: 0.8651
# Epoch 12/100
# 125/125 [==============================] - 11s 92ms/step - loss: 0.3586 - accuracy: 0.8923 - val_loss: 0.4490 - val_accuracy: 0.8675
# Epoch 13/100
# 125/125 [==============================] - 11s 92ms/step - loss: 0.3441 - accuracy: 0.8966 - val_loss: 0.4472 - val_accuracy: 0.8670
# Epoch 14/100
# 125/125 [==============================] - 11s 92ms/step - loss: 0.3298 - accuracy: 0.9010 - val_loss: 0.4344 - val_accuracy: 0.8722
# Epoch 15/100
# 125/125 [==============================] - 11s 91ms/step - loss: 0.3165 - accuracy: 0.9049 - val_loss: 0.4306 - val_accuracy: 0.8731
# Epoch 16/100
# 125/125 [==============================] - 11s 91ms/step - loss: 0.3042 - accuracy: 0.9084 - val_loss: 0.4247 - val_accuracy: 0.8751
# Epoch 17/100
# 125/125 [==============================] - 12s 93ms/step - loss: 0.2922 - accuracy: 0.9119 - val_loss: 0.4230 - val_accuracy: 0.8759
# Epoch 18/100
# 125/125 [==============================] - 12s 93ms/step - loss: 0.2813 - accuracy: 0.9153 - val_loss: 0.4210 - val_accuracy: 0.8774
# Epoch 19/100
# 125/125 [==============================] - 12s 94ms/step - loss: 0.2707 - accuracy: 0.9183 - val_loss: 0.4191 - val_accuracy: 0.8790
# Epoch 20/100
# 125/125 [==============================] - 12s 92ms/step - loss: 0.2604 - accuracy: 0.9217 - val_loss: 0.4181 - val_accuracy: 0.8793
# Epoch 21/100
# 125/125 [==============================] - 12s 94ms/step - loss: 0.2510 - accuracy: 0.9241 - val_loss: 0.4188 - val_accuracy: 0.8788
# Epoch 22/100
# 125/125 [==============================] - 12s 96ms/step - loss: 0.2420 - accuracy: 0.9267 - val_loss: 0.4222 - val_accuracy: 0.8795
# Epoch 23/100
# 125/125 [==============================] - 13s 101ms/step - loss: 0.2330 - accuracy: 0.9298 - val_loss: 0.4223 - val_accuracy: 0.8798
# Epoch 24/100
# 125/125 [==============================] - 12s 100ms/step - loss: 0.2246 - accuracy: 0.9320 - val_loss: 0.4200 - val_accuracy: 0.8814
# Epoch 25/100
# 125/125 [==============================] - 12s 92ms/step - loss: 0.2165 - accuracy: 0.9347 - val_loss: 0.4198 - val_accuracy: 0.8819
# Epoch 26/100
# 125/125 [==============================] - 12s 92ms/step - loss: 0.2092 - accuracy: 0.9367 - val_loss: 0.4231 - val_accuracy: 0.8817
# Epoch 27/100
# 125/125 [==============================] - 12s 93ms/step - loss: 0.2020 - accuracy: 0.9387 - val_loss: 0.4264 - val_accuracy: 0.8815
# Epoch 28/100
# 125/125 [==============================] - 12s 95ms/step - loss: 0.1949 - accuracy: 0.9411 - val_loss: 0.4286 - val_accuracy: 0.8824
# Epoch 29/100
# 125/125 [==============================] - 12s 96ms/step - loss: 0.1885 - accuracy: 0.9429 - val_loss: 0.4335 - val_accuracy: 0.8823
# Epoch 30/100
# 125/125 [==============================] - 12s 92ms/step - loss: 0.1822 - accuracy: 0.9446 - val_loss: 0.4356 - val_accuracy: 0.8814
# Epoch 31/100
# 125/125 [==============================] - 12s 93ms/step - loss: 0.1766 - accuracy: 0.9462 - val_loss: 0.4357 - val_accuracy: 0.8832
# Epoch 32/100
# 125/125 [==============================] - 12s 92ms/step - loss: 0.1707 - accuracy: 0.9479 - val_loss: 0.4412 - val_accuracy: 0.8836
# Epoch 33/100
# 125/125 [==============================] - 12s 93ms/step - loss: 0.1655 - accuracy: 0.9492 - val_loss: 0.4450 - val_accuracy: 0.8822
# Epoch 34/100
# 125/125 [==============================] - 11s 92ms/step - loss: 0.1601 - accuracy: 0.9512 - val_loss: 0.4479 - val_accuracy: 0.8831
# Epoch 35/100
# 125/125 [==============================] - 11s 92ms/step - loss: 0.1551 - accuracy: 0.9524 - val_loss: 0.4528 - val_accuracy: 0.8830
# Epoch 36/100
# 125/125 [==============================] - 12s 93ms/step - loss: 0.1502 - accuracy: 0.9542 - val_loss: 0.4579 - val_accuracy: 0.8826
# Epoch 37/100
# 125/125 [==============================] - 12s 93ms/step - loss: 0.1459 - accuracy: 0.9552 - val_loss: 0.4635 - val_accuracy: 0.8826
# Epoch 38/100
# 125/125 [==============================] - 12s 92ms/step - loss: 0.1413 - accuracy: 0.9566 - val_loss: 0.4688 - val_accuracy: 0.8818
# Epoch 39/100
# 125/125 [==============================] - 11s 92ms/step - loss: 0.1372 - accuracy: 0.9577 - val_loss: 0.4659 - val_accuracy: 0.8834
# Epoch 40/100
# 125/125 [==============================] - 11s 91ms/step - loss: 0.1331 - accuracy: 0.9590 - val_loss: 0.4769 - val_accuracy: 0.8820
# Epoch 41/100
# 125/125 [==============================] - 11s 92ms/step - loss: 0.1292 - accuracy: 0.9601 - val_loss: 0.4722 - val_accuracy: 0.8831
# Epoch 42/100
# 125/125 [==============================] - 12s 95ms/step - loss: 0.1256 - accuracy: 0.9610 - val_loss: 0.4852 - val_accuracy: 0.8822
# Epoch 43/100
# 125/125 [==============================] - 12s 97ms/step - loss: 0.1221 - accuracy: 0.9622 - val_loss: 0.4900 - val_accuracy: 0.8830
# Epoch 44/100
# 125/125 [==============================] - 14s 113ms/step - loss: 0.1185 - accuracy: 0.9634 - val_loss: 0.4909 - val_accuracy: 0.8822
# Epoch 45/100
# 125/125 [==============================] - 14s 110ms/step - loss: 0.1155 - accuracy: 0.9642 - val_loss: 0.4991 - val_accuracy: 0.8822
# Epoch 46/100
# 125/125 [==============================] - 13s 101ms/step - loss: 0.1120 - accuracy: 0.9651 - val_loss: 0.5022 - val_accuracy: 0.8825
# Epoch 47/100
# 125/125 [==============================] - 13s 101ms/step - loss: 0.1090 - accuracy: 0.9661 - val_loss: 0.5113 - val_accuracy: 0.8804
# Epoch 48/100
# 125/125 [==============================] - 13s 105ms/step - loss: 0.1064 - accuracy: 0.9667 - val_loss: 0.5108 - val_accuracy: 0.8816
# Epoch 49/100
# 125/125 [==============================] - 13s 103ms/step - loss: 0.1034 - accuracy: 0.9676 - val_loss: 0.5123 - val_accuracy: 0.8827
# Epoch 50/100
# 125/125 [==============================] - 12s 96ms/step - loss: 0.1007 - accuracy: 0.9684 - val_loss: 0.5187 - val_accuracy: 0.8818
# Epoch 51/100
# 125/125 [==============================] - 12s 92ms/step - loss: 0.0982 - accuracy: 0.9691 - val_loss: 0.5240 - val_accuracy: 0.8810
# Epoch 52/100
# 125/125 [==============================] - 12s 94ms/step - loss: 0.0957 - accuracy: 0.9699 - val_loss: 0.5295 - val_accuracy: 0.8819
# Epoch 53/100
# 125/125 [==============================] - 12s 95ms/step - loss: 0.0934 - accuracy: 0.9705 - val_loss: 0.5342 - val_accuracy: 0.8815
# Epoch 54/100
# 125/125 [==============================] - 12s 95ms/step - loss: 0.0907 - accuracy: 0.9713 - val_loss: 0.5406 - val_accuracy: 0.8808
# Epoch 55/100
# 125/125 [==============================] - 12s 96ms/step - loss: 0.0891 - accuracy: 0.9718 - val_loss: 0.5456 - val_accuracy: 0.8813
# Epoch 56/100
# 125/125 [==============================] - 12s 95ms/step - loss: 0.0872 - accuracy: 0.9724 - val_loss: 0.5458 - val_accuracy: 0.8818
# Epoch 57/100
# 125/125 [==============================] - 12s 97ms/step - loss: 0.0848 - accuracy: 0.9730 - val_loss: 0.5530 - val_accuracy: 0.8803
# Epoch 58/100
# 125/125 [==============================] - 12s 98ms/step - loss: 0.0826 - accuracy: 0.9735 - val_loss: 0.5575 - val_accuracy: 0.8807
# Epoch 59/100
# 125/125 [==============================] - 12s 98ms/step - loss: 0.0807 - accuracy: 0.9741 - val_loss: 0.5593 - val_accuracy: 0.8810
# Epoch 60/100
# 125/125 [==============================] - 12s 93ms/step - loss: 0.0792 - accuracy: 0.9746 - val_loss: 0.5657 - val_accuracy: 0.8812
# Epoch 61/100
# 125/125 [==============================] - 12s 93ms/step - loss: 0.0775 - accuracy: 0.9748 - val_loss: 0.5640 - val_accuracy: 0.8807
# Epoch 62/100
# 125/125 [==============================] - 12s 95ms/step - loss: 0.0758 - accuracy: 0.9753 - val_loss: 0.5690 - val_accuracy: 0.8812
# Epoch 63/100
# 125/125 [==============================] - 12s 93ms/step - loss: 0.0741 - accuracy: 0.9759 - val_loss: 0.5761 - val_accuracy: 0.8817
# Epoch 64/100
# 125/125 [==============================] - 12s 92ms/step - loss: 0.0724 - accuracy: 0.9763 - val_loss: 0.5814 - val_accuracy: 0.8809
# Epoch 65/100
# 125/125 [==============================] - 12s 93ms/step - loss: 0.0708 - accuracy: 0.9770 - val_loss: 0.5904 - val_accuracy: 0.8804
# Epoch 66/100
# 125/125 [==============================] - 12s 95ms/step - loss: 0.0693 - accuracy: 0.9774 - val_loss: 0.5933 - val_accuracy: 0.8804
# Epoch 67/100
# 125/125 [==============================] - 12s 93ms/step - loss: 0.0679 - accuracy: 0.9774 - val_loss: 0.5958 - val_accuracy: 0.8797
# Epoch 68/100
# 125/125 [==============================] - 12s 95ms/step - loss: 0.0668 - accuracy: 0.9780 - val_loss: 0.5963 - val_accuracy: 0.8801
# Epoch 69/100
# 125/125 [==============================] - 12s 98ms/step - loss: 0.0654 - accuracy: 0.9783 - val_loss: 0.6000 - val_accuracy: 0.8804
# Epoch 70/100
# 125/125 [==============================] - 13s 101ms/step - loss: 0.0637 - accuracy: 0.9788 - val_loss: 0.6027 - val_accuracy: 0.8800
# Epoch 71/100
# 125/125 [==============================] - 13s 100ms/step - loss: 0.0630 - accuracy: 0.9791 - val_loss: 0.6078 - val_accuracy: 0.8800
# Epoch 72/100
# 125/125 [==============================] - 12s 94ms/step - loss: 0.0619 - accuracy: 0.9792 - val_loss: 0.6136 - val_accuracy: 0.8800
# Epoch 73/100
# 125/125 [==============================] - 12s 93ms/step - loss: 0.0604 - accuracy: 0.9798 - val_loss: 0.6141 - val_accuracy: 0.8799
# Epoch 74/100
# 125/125 [==============================] - 12s 93ms/step - loss: 0.0596 - accuracy: 0.9799 - val_loss: 0.6242 - val_accuracy: 0.8796
# Epoch 75/100
# 125/125 [==============================] - 12s 93ms/step - loss: 0.0582 - accuracy: 0.9804 - val_loss: 0.6266 - val_accuracy: 0.8801
# Epoch 76/100
# 125/125 [==============================] - 12s 94ms/step - loss: 0.0574 - accuracy: 0.9806 - val_loss: 0.6334 - val_accuracy: 0.8795
# Epoch 77/100
# 125/125 [==============================] - 12s 94ms/step - loss: 0.0564 - accuracy: 0.9809 - val_loss: 0.6313 - val_accuracy: 0.8804
# Epoch 78/100
# 125/125 [==============================] - 12s 93ms/step - loss: 0.0555 - accuracy: 0.9810 - val_loss: 0.6385 - val_accuracy: 0.8799
# Epoch 79/100
# 125/125 [==============================] - 12s 95ms/step - loss: 0.0545 - accuracy: 0.9814 - val_loss: 0.6378 - val_accuracy: 0.8795
# Epoch 80/100
# 125/125 [==============================] - 12s 94ms/step - loss: 0.0538 - accuracy: 0.9814 - val_loss: 0.6417 - val_accuracy: 0.8804
# Epoch 81/100
# 125/125 [==============================] - 12s 94ms/step - loss: 0.0530 - accuracy: 0.9817 - val_loss: 0.6462 - val_accuracy: 0.8798
# Epoch 82/100
# 125/125 [==============================] - 12s 93ms/step - loss: 0.0521 - accuracy: 0.9821 - val_loss: 0.6489 - val_accuracy: 0.8806
# Epoch 83/100
# 125/125 [==============================] - 12s 94ms/step - loss: 0.0514 - accuracy: 0.9822 - val_loss: 0.6517 - val_accuracy: 0.8794
# Epoch 84/100
# 125/125 [==============================] - 12s 94ms/step - loss: 0.0503 - accuracy: 0.9826 - val_loss: 0.6567 - val_accuracy: 0.8797
# Epoch 85/100
# 125/125 [==============================] - 12s 93ms/step - loss: 0.0500 - accuracy: 0.9827 - val_loss: 0.6576 - val_accuracy: 0.8794
# Epoch 86/100
# 125/125 [==============================] - 12s 94ms/step - loss: 0.0491 - accuracy: 0.9829 - val_loss: 0.6628 - val_accuracy: 0.8797
# Epoch 87/100
# 125/125 [==============================] - 12s 94ms/step - loss: 0.0486 - accuracy: 0.9830 - val_loss: 0.6647 - val_accuracy: 0.8795
# Epoch 88/100
# 125/125 [==============================] - 12s 94ms/step - loss: 0.0476 - accuracy: 0.9833 - val_loss: 0.6631 - val_accuracy: 0.8801
# Epoch 89/100
# 125/125 [==============================] - 12s 92ms/step - loss: 0.0474 - accuracy: 0.9834 - val_loss: 0.6674 - val_accuracy: 0.8799
# Epoch 90/100
# 125/125 [==============================] - 12s 93ms/step - loss: 0.0466 - accuracy: 0.9836 - val_loss: 0.6664 - val_accuracy: 0.8802
# Epoch 91/100
# 125/125 [==============================] - 12s 94ms/step - loss: 0.0459 - accuracy: 0.9838 - val_loss: 0.6701 - val_accuracy: 0.8798
# Epoch 92/100
# 125/125 [==============================] - 12s 93ms/step - loss: 0.0455 - accuracy: 0.9838 - val_loss: 0.6753 - val_accuracy: 0.8798
# Epoch 93/100
# 125/125 [==============================] - 12s 92ms/step - loss: 0.0448 - accuracy: 0.9842 - val_loss: 0.6752 - val_accuracy: 0.8800
# Epoch 94/100
# 125/125 [==============================] - 12s 94ms/step - loss: 0.0446 - accuracy: 0.9842 - val_loss: 0.6789 - val_accuracy: 0.8801
# Epoch 95/100
# 125/125 [==============================] - 12s 93ms/step - loss: 0.0435 - accuracy: 0.9845 - val_loss: 0.6810 - val_accuracy: 0.8799
# Epoch 96/100
# 125/125 [==============================] - 12s 95ms/step - loss: 0.0431 - accuracy: 0.9844 - val_loss: 0.6833 - val_accuracy: 0.8809
# Epoch 97/100
# 125/125 [==============================] - 12s 94ms/step - loss: 0.0429 - accuracy: 0.9845 - val_loss: 0.6850 - val_accuracy: 0.8804
# Epoch 98/100
# 125/125 [==============================] - 12s 95ms/step - loss: 0.0425 - accuracy: 0.9848 - val_loss: 0.6948 - val_accuracy: 0.8790
# Epoch 99/100
# 125/125 [==============================] - 12s 95ms/step - loss: 0.0421 - accuracy: 0.9848 - val_loss: 0.6954 - val_accuracy: 0.8800
# Epoch 100/100
# 125/125 [==============================] - 12s 93ms/step - loss: 0.0417 - accuracy: 0.9847 - val_loss: 0.6974 - val_accuracy: 0.8801
# WARNING:tensorflow:From d:\anaconda\envs\py38\lib\site-packages\tensorflow\python\training\tracking\tracking.py:111: Model.state_updates (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# WARNING:tensorflow:From d:\anaconda\envs\py38\lib\site-packages\tensorflow\python\training\tracking\tracking.py:111: Layer.updates (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# INFO:tensorflow:Assets written to: s2s\assets

# %% [markdown]
# ## Run inference (sampling)
#
# 1. encode input and retrieve initial decoder state
# 2. run one step of decoder with this initial state
# and a "start of sequence" token as target.
# Output will be the next target token.
# 3. Repeat with the current target token and current states

# %%
# Define sampling models
# Restore the model and construct the encoder and decoder.
model = keras.models.load_model("s2s")

encoder_inputs = model.input[0]  # input_1
encoder_outputs, state_h_enc, state_c_enc = model.layers[2].output  # lstm_1
encoder_states = [state_h_enc, state_c_enc]
encoder_model = keras.Model(encoder_inputs, encoder_states)

decoder_inputs = model.input[1]  # input_2
decoder_state_input_h = keras.Input(shape=(latent_dim,))
decoder_state_input_c = keras.Input(shape=(latent_dim,))
decoder_states_inputs = [decoder_state_input_h, decoder_state_input_c]
decoder_lstm = model.layers[3]
decoder_outputs, state_h_dec, state_c_dec = decoder_lstm(
    decoder_inputs, initial_state=decoder_states_inputs
)
decoder_states = [state_h_dec, state_c_dec]
decoder_dense = model.layers[4]
decoder_outputs = decoder_dense(decoder_outputs)
decoder_model = keras.Model(
    [decoder_inputs] + decoder_states_inputs, [decoder_outputs] + decoder_states
)

# Reverse-lookup token index to decode sequences back to
# something readable.
reverse_input_char_index = dict((i, char) for char, i in input_token_index.items())
reverse_target_char_index = dict((i, char) for char, i in target_token_index.items())


def decode_sequence(input_seq):
    # Encode the input as state vectors.
    states_value = encoder_model.predict(input_seq)

    # Generate empty target sequence of length 1.
    target_seq = np.zeros((1, 1, num_decoder_tokens))
    # Populate the first character of target sequence with the start character.
    target_seq[0, 0, target_token_index["\t"]] = 1.0

    # Sampling loop for a batch of sequences
    # (to simplify, here we assume a batch of size 1).
    stop_condition = False
    decoded_sentence = ""
    while not stop_condition:
        output_tokens, h, c = decoder_model.predict([target_seq] + states_value)

        # Sample a token
        sampled_token_index = np.argmax(output_tokens[0, -1, :])
        sampled_char = reverse_target_char_index[sampled_token_index]
        decoded_sentence += sampled_char

        # Exit condition: either hit max length
        # or find stop character.
        if sampled_char == "\n" or len(decoded_sentence) > max_decoder_seq_length:
            stop_condition = True

        # Update the target sequence (of length 1).
        target_seq = np.zeros((1, 1, num_decoder_tokens))
        target_seq[0, 0, sampled_token_index] = 1.0

        # Update states
        states_value = [h, c]
    return decoded_sentence

# %% [markdown]
# You can now generate decoded sentences as such:

# %%
for seq_index in range(20):
    # Take one sequence (part of the training set)
    # for trying out decoding.
    input_seq = encoder_input_data[seq_index : seq_index + 1]
    decoded_sentence = decode_sequence(input_seq)
    print("-")
    print("Input sentence:", input_texts[seq_index])
    print("Decoded sentence:", decoded_sentence)
# Out:
# -
# Input sentence: Go.
# Decoded sentence: Bouge !
#
# -
# Input sentence: Go.
# Decoded sentence: Bouge !
#
# -
# Input sentence: Go.
# Decoded sentence: Bouge !
#
# -
# Input sentence: Go.
# Decoded sentence: Bouge !
#
# -
# Input sentence: Hi.
# Decoded sentence: Salut.
#
# -
# Input sentence: Hi.
# Decoded sentence: Salut.
#
# -
# Input sentence: Run!
# Decoded sentence: Cours !
#
# -
# Input sentence: Run!
# Decoded sentence: Cours !
#
# -
# Input sentence: Run!
# Decoded sentence: Cours !
#
# -
# Input sentence: Run!
# Decoded sentence: Cours !
#
# -
# Input sentence: Run!
# Decoded sentence: Cours !
#
# -
# Input sentence: Run!
# Decoded sentence: Cours !
#
# -
# Input sentence: Run!
# Decoded sentence: Cours !
#
# -
# Input sentence: Run!
# Decoded sentence: Cours !
#
# -
# Input sentence: Run.
# Decoded sentence: Cours !
#
# -
# Input sentence: Run.
# Decoded sentence: Cours !
#
# -
# Input sentence: Run.
# Decoded sentence: Cours !
#
# -
# Input sentence: Run.
# Decoded sentence: Cours !
#
# -
# Input sentence: Run.
# Decoded sentence: Cours !
#
# -
# Input sentence: Run.
# Decoded sentence: Cours !
